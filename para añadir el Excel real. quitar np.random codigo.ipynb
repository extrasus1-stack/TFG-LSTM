# %%
import pandas as pd

print("Cargando datos clínicos desde Excel...")

# 1. Leer las dos pestañas de tu Excel
df_fijos = pd.read_excel("Datos_LMA.xlsx", sheet_name="Datos_Basales")
df_dinamicos = pd.read_excel("Datos_LMA.xlsx", sheet_name="Analiticas_Dinamicas")

# 2. Extraer los resultados de supervivencia (Y)
y_evento = df_fijos['Evento_Recidiva'].values
y_tiempo = df_fijos['Tiempo_Seguimiento_Meses'].values

# (Aquí añadiremos unas líneas para que Python aplique el Z-score a la edad
# y agrupe las analíticas temporales de cada paciente automáticamente).
# Out:
# Cargando datos clínicos desde Excel...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_638/516020270.py in <cell line: 0>()
#       4
#       5 # 1. Leer las dos pestañas de tu Excel
# ----> 6 df_fijos = pd.read_excel("Datos_LMA.xlsx", sheet_name="Datos_Basales")
#       7 df_dinamicos = pd.read_excel("Datos_LMA.xlsx", sheet_name="Analiticas_Dinamicas")
#       8
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
# ...
